# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import glob

# %%
data = np.concatenate([np.load(fn)['arr_0'] for fn in glob.glob("soln?????.npz")])

# %%
contourf(data['fc'])
colorbar
# Out:
# <function matplotlib.pyplot.colorbar>
